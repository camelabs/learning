# %%
import pandas as pd

# %%
data=pd.read_csv("/media/ashley/5011e0b1-5fd0-4a93-b3f6-892e8cb26354/IBM Transactions for Anti Money Laundering (AML)/LI-Small_Patterns.csv")
data
# Out:
#                                               Timestamp  From Bank    Account  \
# 0                                      2022/09/01 02:38     1812.0  80279F810
# 1                                      2022/09/02 14:36    22595.0  80279F8B0
# 2                                      2022/09/03 14:09     1120.0  800E36A50
# 3                       END LAUNDERING ATTEMPT - FAN-IN        NaN        NaN
# 4                                                   NaN        NaN        NaN
# ...                                                 ...        ...        ...
# 1367                                                NaN        NaN        NaN
# 1368  BEGIN LAUNDERING ATTEMPT - GATHER-SCATTER:  Ma...        NaN        NaN
# 1369                                   2022/09/10 22:10    15516.0  8026EA390
# 1370                                   2022/09/10 15:58    25788.0  8026EA1A0
# 1371            END LAUNDERING ATTEMPT - GATHER-SCATTER        NaN        NaN
#
# ...

# %%
data.head(10)
# Out:
#                                            Timestamp  From Bank    Account  \
# 0                                   2022/09/01 02:38     1812.0  80279F810
# 1                                   2022/09/02 14:36    22595.0  80279F8B0
# 2                                   2022/09/03 14:09     1120.0  800E36A50
# 3                    END LAUNDERING ATTEMPT - FAN-IN        NaN        NaN
# 4                                                NaN        NaN        NaN
# 5  BEGIN LAUNDERING ATTEMPT - FAN-IN:  Max 8-degr...        NaN        NaN
# 6                                   2022/09/01 03:17     3671.0  801BF8E70
# 7                                   2022/09/01 06:27       15.0  80074C7E0
# 8                                   2022/09/01 10:04     2557.0  80107C9A0
# 9                                   2022/09/02 06:35       12.0  800A9B180
#
#    To Bank  Account.1  Amount Received Receiving Currency  Amount Paid  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           1256 non-null   object
#  1   From Bank           1023 non-null   float64
#  2   Account             1023 non-null   object
#  3   To Bank             1023 non-null   float64
#  4   Account.1           1023 non-null   object
#  5   Amount Received     1023 non-null   float64
#  6   Receiving Currency  1023 non-null   object
#  7   Amount Paid         1023 non-null   float64
#  8   Payment Currency    1023 non-null   object
#  9   Payment Format      1023 non-null   object
#  10  Is Laundering       1023 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 118.0+ KB

# %%
data.describe()
# Out:
#            From Bank        To Bank  Amount Received   Amount Paid  \
# count    1023.000000    1023.000000     1.023000e+03  1.023000e+03
# mean     9685.884653   11114.734115     3.921572e+06  3.921572e+06
# std     28795.301049   31987.075561     6.716403e+07  6.716403e+07
# min         0.000000       0.000000     6.000000e-02  6.000000e-02
# 25%        20.000000      20.000000     4.311585e+03  4.311585e+03
# 50%      1217.000000    1231.000000     9.175320e+03  9.175320e+03
# 75%     11047.000000   11495.000000     1.471589e+04  1.471589e+04
# max    238669.000000  249331.000000     1.927898e+09  1.927898e+09
#
#        Is Laundering
# count         1023.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
cleaned_LI_small_patterns=data.dropna()

# %%
print(cleaned_LI_small_patterns)
# Out:
#              Timestamp  From Bank    Account  To Bank  Account.1  \
# 0     2022/09/01 02:38     1812.0  80279F810    110.0  8000A94C0
# 1     2022/09/02 14:36    22595.0  80279F8B0    110.0  8000A94C0
# 2     2022/09/03 14:09     1120.0  800E36A50    110.0  8000A94C0
# 6     2022/09/01 03:17     3671.0  801BF8E70   2557.0  8016B3750
# 7     2022/09/01 06:27       15.0  80074C7E0   2557.0  8016B3750
# ...                ...        ...        ...      ...        ...
# 1363  2022/09/14 09:36       27.0  80BF623F0  27009.0  80B880140
# 1364  2022/09/14 10:06       27.0  80BF623F0  16934.0  805F5B360
# 1365  2022/09/14 14:10       27.0  80BF623F0    531.0  8057B5070
# 1369  2022/09/10 22:10    15516.0  8026EA390  25788.0  8026EA1A0
# 1370  2022/09/10 15:58    25788.0  8026EA1A0  25788.0  8026EA1A0
#
#       Amount Received Receiving Currency  Amount Paid   Payment Currency  \
# 0            10154.74  Australian Dollar     10154.74  Australian Dollar
# ...

# %%
cleaned_LI_small_patterns.head(40)
# Out:
#            Timestamp  From Bank    Account  To Bank  Account.1  \
# 0   2022/09/01 02:38     1812.0  80279F810    110.0  8000A94C0
# 1   2022/09/02 14:36    22595.0  80279F8B0    110.0  8000A94C0
# 2   2022/09/03 14:09     1120.0  800E36A50    110.0  8000A94C0
# 6   2022/09/01 03:17     3671.0  801BF8E70   2557.0  8016B3750
# 7   2022/09/01 06:27       15.0  80074C7E0   2557.0  8016B3750
# 8   2022/09/01 10:04     2557.0  80107C9A0   2557.0  8016B3750
# 9   2022/09/02 06:35       12.0  800A9B180   2557.0  8016B3750
# 10  2022/09/03 09:12    21393.0  801271170   2557.0  8016B3750
# 11  2022/09/03 13:45     2175.0  801E25F20   2557.0  8016B3750
# 12  2022/09/03 16:17       20.0  800043BE0   2557.0  8016B3750
# 13  2022/09/03 23:09    22124.0  8011D0180   2557.0  8016B3750
# 17  2022/09/01 03:52    23848.0  801A0BEB0   1835.0  800F963A0
# 18  2022/09/01 05:37      498.0  8013B3270   1835.0  800F963A0
# 19  2022/09/02 03:28      349.0  80049FE00   1835.0  800F963A0
# ...

# %%
cleaned_LI_small_patterns.to_csv("cleaned_LI_small_patterns.csv", index=False)

# %%
cleaned_LI_small_patterns.isna().sum()
# Out:
# Timestamp             0
# From Bank             0
# Account               0
# To Bank               0
# Account.1             0
# Amount Received       0
# Receiving Currency    0
# Amount Paid           0
# Payment Currency      0
# Payment Format        0
# Is Laundering         0
# dtype: int64
